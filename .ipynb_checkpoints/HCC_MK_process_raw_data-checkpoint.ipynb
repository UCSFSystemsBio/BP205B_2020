# %%
import numpy as np
import pandas as pd
import scanpy as sc
import anndata

# %%
sc.settings.verbosity = 2             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_versions()
sc.settings.set_figure_params(dpi=80)
# Out:
# scanpy==1.4.5.1 anndata==0.7.1 umap==0.3.10 numpy==1.17.2 scipy==1.3.1 pandas==0.25.1 scikit-learn==0.21.3 statsmodels==0.10.1

# %%
from process_raw_data import *

# %% [markdown]
# ### Set up processing parameters

# %%
cellBCpath = 'barcodes/MK_barcode_identities.csv'
geneBCpath = 'barcodes/sample_barcodes/HCC_MK_multiseq_barcodes.txt'
matrixPath = '/wynton/scratch/bp205/raw/HCC_MK/filtered_gene_bc_matrices/GRCh38/'

outfilePathFiltNorm = '/wynton/scratch/bp205/processed/HCC_MK_filtered_normalized_adata.h5ad'
outfilePathFiltNorm_loom = '/wynton/scratch/bp205/processed/HCC_MK_filtered_normalized_adata.loom'
outfilePathFiltNorm_R = '/wynton/scratch/bp205/processed/HCC_MK_filtered_normalized_adata_R/'
outfilePathFiltNorm_csv = '/wynton/scratch/bp205/processed/HCC_MK_filtered_normalized_adata_R/HCC_MK_filtered_normalized_adata.csv'

outfilePathFilt = '/wynton/scratch/bp205/processed/HCC_MK_filtered_adata.h5ad'
outfilePathFilt_loom = '/wynton/scratch/bp205/processed/HCC_MK_filtered_adata.loom'
outfilePathFilt_R = '/wynton/scratch/bp205/processed/HCC_MK_filtered_adata_R/'
outfilePathFilt_csv = '/wynton/scratch/bp205/processed/HCC_MK_normalized_adata_R/HCC_MK_filtered_adata.csv'

outfilePathNorm = '/wynton/scratch/bp205/processed/HCC_MK_normalized_adata.h5ad'
outfilePathNorm_loom = '/wynton/scratch/bp205/processed/HCC_MK_normalized_adata.loom'
outfilePathNorm_R = '/wynton/scratch/bp205/processed/HCC_MK_normalized_adata_R/'
outfilePathNorm_csv = '/wynton/scratch/bp205/processed/HCC_MK_normalized_adata_R/HCC_MK_normalized_adata.csv'

outfilePath = '/wynton/scratch/bp205/processed/HCC_MK_adata.h5ad'
outfilePath_loom = '/wynton/scratch/bp205/processed/HCC_MK_adata.loom'
outfilePath_R = '/wynton/scratch/bp205/processed/HCC_MK_adata_R/'
outfilePath_csv = '/wynton/scratch/bp205/processed/HCC_MK_adata_R/HCC_MK_adata.csv'


minN_genes = 200
minN_cells = 3
maxN_genes = 6000
maxMito_percent = 0.07

# %% [markdown]
# ### Load Cell barcodes and Sample barcodes

# %%
cellBC = pd.read_csv(cellBCpath, usecols=[1,2,3],
#cellBC = cellBC[cellBC['multiseq barcode']!='DOUBLET']

geneBC = pd.read_csv(geneBCpath, sep='\t', index_col=0)
#BCmap = create_barcode_map(cellBC, geneBC)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-b1962a1f4bfb> in <module>
# ----> 1 cellBC = pd.read_csv(cellBCpath, usecols=[1,2,3],index=None)
#       2 #cellBC = cellBC[cellBC['multiseq barcode']!='DOUBLET']
#       3
#       4 geneBC = pd.read_csv(geneBCpath, sep='\t', index_col=0)
#       5 #BCmap = create_barcode_map(cellBC, geneBC)
#
# TypeError: parser_f() got an unexpected keyword argument 'index'

# %%
cellBC
# Out:
#             Unnamed: 0 cell barcode multiseq barcode
# 0     ATGTGTGTCACAGGCC     TCCCCTTT              NaN
# 1     GCTTCCACACATCTTT     TCCCCTTT              NaN
# 2     CGGCTAGCAGCCAGAA     CTCGGAAT              NaN
# 3     GATCGATAGTCATGCT     TCCCCTTT              NaN
# 4     ACACCCTTCCACGCAG     CTCGGAAT              NaN
# ...                ...          ...              ...
# 8859  GGTGTTATCAGGATCT     CTCGGAAT              NaN
# 8860  TCACAAGAGCGTTTAC     CTCGGAAT              NaN
# 8861  GTAGGCCGTGGTAACG     GGCCGGTT              NaN
# 8862  GTAACTGAGTAGGTGC     CTCGGAAT              NaN
# 8863  CTCCTAGGTGGTGTAG     CTCGGAAT              NaN
#
# [8864 rows x 3 columns]

# %%
BCmap = create_barcode_map(cellBC, geneBC)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: nan
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ff7221d63f02> in <module>
# ----> 1 BCmap = create_barcode_map(cellBC, geneBC)
#
# ~/rds/bp205/processing/process_raw_data.py in create_barcode_map(cellBC, geneBC)
#       7     BCmap['SampleType']=""
#       8     for row in BCmap.index:
# ----> 9         BCmap.loc[row,'SampleType'] = geneBC.loc[BCmap.loc[row]['multiseq barcode']]['Sample']
#      10     BCmap=BCmap.set_index('cell barcode')
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: nan

# %%
BCmap.head()

# %% [markdown]
# ### Loading raw sample x gene counts matrix

# %%
adata = read_matrix(matrixPath)
# Out:
# ... reading from cache file cache/wynton-scratch-bp205-raw-HCC_MK-filtered_gene_bc_matrices-GRCh38-matrix.h5ad

# %%
adata = add_cell_type_to_obs(adata, BCmap)

# %% [markdown]
# ### Visalizing the highest expression genes

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %% [markdown]
# Remove cells with fewer gene counts than a detection threshold, and are found in fewer than $n$ cells

# %%
adata = filter_minGenes_minCells(adata, minN_genes, minN_cells)
# Out:
# filtered out 13984 genes that are detected in less than 3 cells

# %% [markdown]
# Remove all cells which are not mapped to a specific sample (due to degenerate MULTI or genetic barcodes)

# %%
adata = keep_real_cells(adata)

# %% [markdown]
# ### Determining % mitochondria-associated genes

# %%
adata = calc_percentMito_nCounts(adata)
sc.pl.violin(adata, ['n_genes', 'n_counts', 'percent_mito'],
             jitter=0.4, multi_panel=True)
# Out:
# Trying to set attribute `.obs` of view, copying.
# ... storing 'SampleType' as categorical

# %%
sc.pl.scatter(adata, x='n_counts', y='percent_mito')
sc.pl.scatter(adata, x='n_counts', y='n_genes')

# %% [markdown]
# ### Filtering out cells with high gene counts, and high mitochondrial percentage

# %%
adata = filter_genes_mito(adata, maxN_genes, maxMito_percent)

# %%
adata.shape
# Out:
# (8556, 19710)

# %% [markdown]
# ### Normalize count matrix (Total Normalization) and log-transform the count values

# %%
adata, backup = normalize_and_log(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:18)
# /wynton/home/students/snanda/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:298: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(data)

# %%
## Save an unnormalized, unprocessed version of the file
backup.write(outfilePath)
backup.write_loom(outfilePath_loom)
backup.write_csvs(outfilePath_R)
np.savetxt(outfilePath_csv,backup.X.todense(),delimiter=',')
# Out:
# writing .csv files to /wynton/scratch/bp205/processed/HCC_MK_adata_R

# %%
## Save a processed version of the file
adata.write(outfilePathNorm)
adata.write_loom(outfilePathNorm_loom)
adata.write_csvs(outfilePathNorm_R)
np.savetxt(outfilePathNorm_csv,adata.X.todense(),delimiter=',')
# Out:
# writing .csv files to /wynton/scratch/bp205/processed/HCC_MK_normalized_adata_R

# %% [markdown]
# ### Plot highly variable genes

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.02, max_mean=4, min_disp=0.2)
sc.pl.highly_variable_genes(adata)
# Out:
# extracting highly variable genes
# /wynton/home/students/snanda/anaconda3/lib/python3.7/site-packages/scanpy/preprocessing/_highly_variable_genes.py:58: RuntimeWarning: invalid value encountered in log
#   dispersion = np.log(dispersion)
#     finished (0:00:02)

# %% [markdown]
# ### Keep only genes which are 'highly variable'

# %%
backup_filtered = backup.copy()[:,adata.var.highly_variable]
backup_filtered.write(outfilePathFilt)
backup_filtered.write_loom(outfilePathFilt_loom)
backup_filtered.write_csvs(outfilePathFilt_R)
np.savetxt(outfilePathFilt_csv,backup_filtered.X.todense(),delimiter=',')
# Out:
# writing .csv files to /wynton/scratch/bp205/processed/HCC_MK_filtered_adata_R

# %%
adata = adata[:, adata.var.highly_variable]

# %% [markdown]
# ### Regress out the mitochondrial fraction and total counts, rescale the data, and perform PCA

# %%
adata = regress_scale_pca(adata)
# Out:
# regressing out ['n_counts', 'percent_mito']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:21)
# computing PCA with n_comps = 50
#     on highly variable genes
#     finished (0:00:04)

# %%
## Save a processed version of the file
adata.write(outfilePathFiltNorm)
adata.write_loom(outfilePathFiltNorm_loom)
adata.write_csvs(outfilePathFiltNorm_R)
np.savetxt(outfilePathFiltNorm_csv,adata.X,delimiter=',')
# Out:
# The loom file will lack these fields:
# {'X_pca', 'PCs'}
# Use write_obsm_varm=True to export multi-dimensional annotations
# writing .csv files to /wynton/scratch/bp205/processed/HCC_MK_filtered_normalized_adata_R
